# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')  # esto es para quitar prints

pd.set_option('display.max_columns', None)   # mostrar todas las columnas del df
#pd.set_option('display.max_rows', None)   # mostrar todas las filas del df

# %% [markdown]
# Exploración de los datos dentro de actor

# %%
actor = pd.read_csv('../w3-database-project/data/actor.csv')

actor.head(10)
# Out:
#    actor_id                 name
# 0         1     PENELOPE GUINESS
# 1         2        NICK WAHLBERG
# 2         3             ED CHASE
# 3         4       JENNIFER DAVIS
# 4         5  JOHNNY LOLLOBRIGIDA
# 5         6      BETTE NICHOLSON
# 6         7         GRACE MOSTEL
# 7         8    MATTHEW JOHANSSON
# 8         9            JOE SWANK
# 9        10      CHRISTIAN GABLE

# %%
actor.drop(columns='last_update', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 actor.drop(columns='last_update', inplace=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
actor.shape
# Out:
# (200, 2)

# %%
actor.head(10)
# Out:
#    actor_id                 name
# 0         1     PENELOPE GUINESS
# 1         2        NICK WAHLBERG
# 2         3             ED CHASE
# 3         4       JENNIFER DAVIS
# 4         5  JOHNNY LOLLOBRIGIDA
# 5         6      BETTE NICHOLSON
# 6         7         GRACE MOSTEL
# 7         8    MATTHEW JOHANSSON
# 8         9            JOE SWANK
# 9        10      CHRISTIAN GABLE

# %%
actor.value_counts()
# Out:
# actor_id  name
# 1         PENELOPE GUINESS        1
# 138       LUCILLE DEE             1
# 128       CATE MCQUEEN            1
# 129       DARYL CRAWFORD          1
# 130       GRETA KEITEL            1
#                                  ..
# 70        MICHELLE MCCONAUGHEY    1
# 71        ADAM GRANT              1
# 72        SEAN WILLIAMS           1
# 73        GARY PENN               1
# 200       THORA TEMPLE            1
# Length: 200, dtype: int64

# %%
actor.dtypes
# Out:
# actor_id     int64
# name        object
# dtype: object

# %%
actor.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   actor_id  200 non-null    int64
#  1   name      200 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 15.3 KB

# %%
actor.drop_duplicates().shape==actor.shape
# Out:
# True

# %%
actor.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   actor_id  200 non-null    int64
#  1   name      200 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 15.3 KB

# %%
actor['name'] = actor.first_name + ' ' + actor.last_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 actor['name'] = actor.first_name + ' ' + actor.last_name
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'first_name'

# %%
col =['first_name','last_name']
actor.drop(columns=col, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [12], in <cell line: 2>()
#       1 col =['first_name','last_name']
# ----> 2 actor.drop(columns=col, inplace=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
# ...

# %% [markdown]
# Exploración de los datos de category

# %%
category = pd.read_csv('../w3-database-project/data/category.csv')

category.head(10)
# Out:
#    category_id         name
# 0            1       Action
# 1            2    Animation
# 2            3     Children
# 3            4     Classics
# 4            5       Comedy
# 5            6  Documentary
# 6            7        Drama
# 7            8       Family
# 8            9      Foreign
# 9           10        Games

# %%
category.drop(columns='last_update', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 category.drop(columns='last_update', inplace=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
category.shape

# %%
category.value_counts()
# Out:
# category_id  name
# 1            Action         1
# 2            Animation      1
# 3            Children       1
# 4            Classics       1
# 5            Comedy         1
# 6            Documentary    1
# 7            Drama          1
# 8            Family         1
# 9            Foreign        1
# 10           Games          1
# 11           Horror         1
# 12           Music          1
# 13           New            1
# 14           Sci-Fi         1
# 15           Sports         1
# 16           Travel         1
# dtype: int64

# %%
category.dtypes
# Out:
# category_id     int64
# name           object
# dtype: object

# %%
category.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   category_id  16 non-null     int64
#  1   name         16 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.2 KB

# %%
category.drop_duplicates().shape==category.shape
# Out:
# True

# %% [markdown]
# Exploración de los datos en film

# %%
film = pd.read_csv('../w3-database-project/data/film.csv')

# %%
film.special_features.unique()
# Out:
# array(['Deleted Scenes,Behind the Scenes', 'Trailers,Deleted Scenes',
#        'Commentaries,Behind the Scenes', 'Deleted Scenes', 'Trailers',
#        'Commentaries,Deleted Scenes',
#        'Trailers,Deleted Scenes,Behind the Scenes',
#        'Trailers,Commentaries,Behind the Scenes', 'Trailers,Commentaries',
#        'Trailers,Behind the Scenes',
#        'Commentaries,Deleted Scenes,Behind the Scenes',
#        'Trailers,Commentaries,Deleted Scenes',
#        'Trailers,Commentaries,Deleted Scenes,Behind the Scenes',
#        'Behind the Scenes', 'Commentaries'], dtype=object)

# %%
film.shape
# Out:
# (1000, 11)

# %%
film.value_counts()
# Out:
# film_id  title             description                                                                                                      release_year  language_id  rental_duration  rental_rate  length  replacement_cost  rating  special_features
# 1        ACADEMY DINOSAUR  A Epic Drama of a Feminist And a Mad Scientist who must Battle a Teacher in The Canadian Rockies                 2006          1            6                0.99         86      20.99             PG      Deleted Scenes,Behind the Scenes                 1
# 672      PERFECT GROOVE    A Thrilling Yarn of a Dog And a Dog who must Build a Husband in A Baloon                                         2006          1            7                2.99         82      17.99             PG-13   Commentaries,Deleted Scenes,Behind the Scenes    1
# ...

# %%
film.dtypes
# Out:
# film_id               int64
# title                object
# description          object
# release_year          int64
# language_id           int64
# rental_duration       int64
# rental_rate         float64
# length                int64
# replacement_cost    float64
# rating               object
# special_features     object
# dtype: object

# %%
film.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   film_id           1000 non-null   int64
#  1   title             1000 non-null   object
#  2   description       1000 non-null   object
#  3   release_year      1000 non-null   int64
#  4   language_id       1000 non-null   int64
#  5   rental_duration   1000 non-null   int64
#  6   rental_rate       1000 non-null   float64
#  7   length            1000 non-null   int64
#  8   replacement_cost  1000 non-null   float64
#  9   rating            1000 non-null   object
#  10  special_features  1000 non-null   object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 413.3 KB

# %%
film.drop_duplicates().shape==film.shape
# Out:
# True

# %%
col=['original_language_id','last_update']
film.drop(columns=col, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       1 col=['original_language_id','last_update']
# ----> 2 film.drop(columns=col, inplace=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
# ...

# %%
film.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   film_id           1000 non-null   int64
#  1   title             1000 non-null   object
#  2   description       1000 non-null   object
#  3   release_year      1000 non-null   int64
#  4   language_id       1000 non-null   int64
#  5   rental_duration   1000 non-null   int64
#  6   rental_rate       1000 non-null   float64
#  7   length            1000 non-null   int64
#  8   replacement_cost  1000 non-null   float64
#  9   rating            1000 non-null   object
#  10  special_features  1000 non-null   object
# dtypes: float64(2), int64(5), object(4)
# memory usage: 413.3 KB

# %%
film.head(10)
# Out:
#    film_id             title  \
# 0        1  ACADEMY DINOSAUR
# 1        2    ACE GOLDFINGER
# 2        3  ADAPTATION HOLES
# 3        4  AFFAIR PREJUDICE
# 4        5       AFRICAN EGG
# 5        6      AGENT TRUMAN
# 6        7   AIRPLANE SIERRA
# 7        8   AIRPORT POLLOCK
# 8        9     ALABAMA DEVIL
# 9       10  ALADDIN CALENDAR
#
#                                          description  release_year  \
# 0  A Epic Drama of a Feminist And a Mad Scientist...          2006
# 1  A Astounding Epistle of a Database Administrat...          2006
# 2  A Astounding Reflection of a Lumberjack And a ...          2006
# 3  A Fanciful Documentary of a Frisbee And a Lumb...          2006
# 4  A Fast-Paced Documentary of a Pastry Chef And ...          2006
# 5  A Intrepid Panorama of a Robot And a Boy who m...          2006
# 6  A Touching Saga of a Hunter And a Butler who m...          2006
# 7  A Epic Tale of a Moose And a Girl who must Con...          2006
# ...

# %% [markdown]
# Exploración de los datos en inventory

# %%
inventory = pd.read_csv('../w3-database-project/data/inventory.csv')

inventory.head()
# Out:
#    inventory_id  film_id  store_id
# 0             1        1         1
# 1             2        1         1
# 2             3        1         1
# 3             4        1         1
# 4             5        1         2

# %%
inventory.drop(columns='last_update', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 inventory.drop(columns='last_update', inplace=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
inventory.shape
# Out:
# (1000, 3)

# %%
inventory.value_counts()
# Out:
# inventory_id  film_id  store_id
# 1             1        1           1
# 672           147      1           1
# 659           143      1           1
# 660           143      1           1
# 661           143      1           1
#                                   ..
# 339           75       2           1
# 340           75       2           1
# 341           75       2           1
# 342           76       1           1
# 1000          223      2           1
# Length: 1000, dtype: int64

# %%
inventory.dtypes
# Out:
# inventory_id    int64
# film_id         int64
# store_id        int64
# dtype: object

# %%
inventory.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   inventory_id  1000 non-null   int64
#  1   film_id       1000 non-null   int64
#  2   store_id      1000 non-null   int64
# dtypes: int64(3)
# memory usage: 23.6 KB

# %%
inventory.drop_duplicates().shape==inventory.shape
# Out:
# True

# %%
language = pd.read_csv('../w3-database-project/data/language.csv')

language.head(10)
# Out:
#    language_id      name
# 0            1   English
# 1            2   Italian
# 2            3  Japanese
# 3            4  Mandarin
# 4            5    French
# 5            6    German

# %%
language.drop(columns='last_update', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 language.drop(columns='last_update', inplace=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
language.shape
# Out:
# (6, 2)

# %%
language.value_counts()
# Out:
# language_id  name
# 1            English     1
# 2            Italian     1
# 3            Japanese    1
# 4            Mandarin    1
# 5            French      1
# 6            German      1
# dtype: int64

# %%
language.dtypes
# Out:
# language_id     int64
# name           object
# dtype: object

# %%
language.drop_duplicates().shape==language.shape
# Out:
# True

# %%
language.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   language_id  6 non-null      int64
#  1   name         6 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 560.0 bytes

# %%
old_HDD = pd.read_csv('../w3-database-project/data/old_HDD.csv')

old_HDD.head(10)
# Out:
#                    title  release_year  category_id              name
# 0       ACADEMY DINOSAUR          2006            6  PENELOPE GUINESS
# 1   ANACONDA CONFESSIONS          2006            2  PENELOPE GUINESS
# 2            ANGELS LIFE          2006           13  PENELOPE GUINESS
# 3  BULWORTH COMMANDMENTS          2006           10  PENELOPE GUINESS
# 4          CHEAPER CLYDE          2006           14  PENELOPE GUINESS
# 5     COLOR PHILADELPHIA          2006            4  PENELOPE GUINESS
# 6        ELEPHANT TROJAN          2006           11  PENELOPE GUINESS
# 7    GLEAMING JAWBREAKER          2006           15  PENELOPE GUINESS
# 8         HUMAN GRAFFITI          2006           10  PENELOPE GUINESS
# 9         KING EVOLUTION          2006            8  PENELOPE GUINESS

# %%
old_HDD.shape
# Out:
# (1000, 4)

# %%
old_HDD.value_counts()
# Out:
# title                  release_year  category_id  name
# ACADEMY DINOSAUR       2006          6            CHRISTIAN GABLE        1
# PACIFIC AMISTAD        2006          6            JOE SWANK              1
# OKLAHOMA JUMANJI       2006          13           PENELOPE GUINESS       1
#                                                   RIP CRAWFORD           1
# OLEANDER CLUE          2006          12           SANDRA KILMER          1
#                                                                         ..
# FIRE WOLVES            2006          10           JOHNNY LOLLOBRIGIDA    1
# FIREBALL PHILADELPHIA  2006          5            VAL BOLGER             1
# FIREHOUSE VIETNAM      2006          1            SANDRA PECK            1
# FLASH WARS             2006          13           DAN TORN               1
# ZHIVAGO CORE           2006          11           UMA WOOD               1
# Length: 1000, dtype: int64

# %%
old_HDD.dtypes
# Out:
# title           object
# release_year     int64
# category_id      int64
# name            object
# dtype: object

# %%
old_HDD.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         1000 non-null   object
#  1   release_year  1000 non-null   int64
#  2   category_id   1000 non-null   int64
#  3   name          1000 non-null   object
# dtypes: int64(2), object(2)
# memory usage: 152.9 KB

# %%
old_HDD.drop_duplicates().shape==old_HDD.shape
# Out:
# True

# %%
old_HDD['name'] = old_HDD.first_name + ' ' + old_HDD.last_name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [49], in <cell line: 1>()
# ----> 1 old_HDD['name'] = old_HDD.first_name + ' ' + old_HDD.last_name
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'first_name'

# %%
col =['first_name','last_name']
old_HDD.drop(columns=col, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [50], in <cell line: 2>()
#       1 col =['first_name','last_name']
# ----> 2 old_HDD.drop(columns=col, inplace=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
# ...

# %% [markdown]
# Exploración de la columna rental

# %%
rental = pd.read_csv('../w3-database-project/data/rental.csv')

rental.head(10)
# Out:
#    rental_id          rental_date  inventory_id  customer_id  \
# 0          1  2005-05-24 22:53:30           367          130
# 1          2  2005-05-24 22:54:33          1525          459
# 2          3  2005-05-24 23:03:39          1711          408
# 3          4  2005-05-24 23:04:41          2452          333
# 4          5  2005-05-24 23:05:21          2079          222
# 5          6  2005-05-24 23:08:07          2792          549
# 6          7  2005-05-24 23:11:53          3995          269
# 7          8  2005-05-24 23:31:46          2346          239
# 8          9  2005-05-25 00:00:40          2580          126
# 9         10  2005-05-25 00:02:21          1824          399
#
#            return_date  staff_id
# 0  2005-05-26 22:04:30         1
# 1  2005-05-28 19:40:33         1
# 2  2005-06-01 22:12:39         1
# 3  2005-06-03 01:43:41         2
# 4  2005-06-02 04:33:21         1
# 5  2005-05-27 01:32:07         1
# 6  2005-05-29 20:34:53         2
# ...

# %%
rental.drop(columns='last_update', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 rental.drop(columns='last_update', inplace=True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
# ...

# %%
rental.shape
# Out:
# (1000, 6)

# %%
rental.value_counts()
# Out:
# rental_id  rental_date          inventory_id  customer_id  return_date          staff_id
# 1          2005-05-24 22:53:30  367           130          2005-05-26 22:04:30  1           1
# 673        2005-05-28 22:07:30  1769          468          2005-06-01 23:42:30  1           1
# 660        2005-05-28 20:53:31  1414          578          2005-05-30 15:26:31  1           1
# 661        2005-05-28 21:01:25  2247          51           2005-06-02 01:22:25  2           1
# 662        2005-05-28 21:09:31  2968          166          2005-06-01 19:00:31  2           1
#                                                                                            ..
# 340        2005-05-27 03:55:25  946           209          2005-06-04 07:57:25  2           1
# 341        2005-05-27 04:01:42  4168          56           2005-06-05 08:51:42  1           1
# 342        2005-05-27 04:11:04  4019          539          2005-05-29 01:28:04  2           1
# ...

# %%
rental.dtypes
# Out:
# rental_id        int64
# rental_date     object
# inventory_id     int64
# customer_id      int64
# return_date     object
# staff_id         int64
# dtype: object

# %%
rental.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   rental_id     1000 non-null   int64
#  1   rental_date   1000 non-null   object
#  2   inventory_id  1000 non-null   int64
#  3   customer_id   1000 non-null   int64
#  4   return_date   1000 non-null   object
#  5   staff_id      1000 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 179.8 KB

# %%
rental.drop_duplicates().shape==rental.shape
# Out:
# True

# %% [markdown]
# Conversión a CSV

# %%
film.to_csv('../w3-database-project/data/film.csv', index=False)

# %%
actor.to_csv('../w3-database-project/data/actor.csv', index=False)

# %%
category.to_csv('../w3-database-project/data/category.csv', index=False)

# %%
inventory.to_csv('../w3-database-project/data/inventory.csv', index=False)

# %%
language.to_csv('../w3-database-project/data/language.csv', index=False)

# %%
old_HDD.to_csv('../w3-database-project/data/old_HDD.csv', index=False)

# %%
rental.to_csv('../w3-database-project/data/rental.csv', index=False)

# %%
# %pip install mysql-connector-python
# %pip install SQLAlchemy
# %pip install pymysql
from sqlalchemy import create_engine
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Pasar a SQL

# %%
with open('../w3-database-project/cont.txt', 'r') as file:
    pass_=file.readlines()
token = ''.join(pass_)f

# %%
str_conn='mysql+pymysql://root:token@localhost:3306/blockbuster'

cursor=create_engine(str_conn)

# %% [markdown]
# actor.to_sql(name='actor', con=cursor, if_exists='replace', index=False)

# %%
category.to_sql(name='category', con=cursor, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3256, in Engine._wrap_pool_connect(self, fn, connection)
#    3255 try:
# -> 3256     return fn()
#    3257 except dialect.dbapi.Error as e:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
language.to_sql(name='language', con=cursor, if_exists='replace', index=False)

# %%
film.to_sql(name='film', con=cursor, if_exists='replace', index=False)

# %%
inventory.to_sql(name='inventory', con=cursor, if_exists='replace', index=False)

# %%
old_HDD.to_sql(name='old_HDD', con=cursor, if_exists='replace', index=False)

# %%
rental.to_sql(name='rental', con=cursor, if_exists='replace', index=False)

# %%
actor.to_sql(name='actor', con=cursor, if_exists='replace', index=False)
